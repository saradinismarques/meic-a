# %% [markdown]
# # AGH - Deep Learning in Medical Image Analysis I
#
# Author: Marek Wodziński
#
# Contact: wodzinski@agh.edu.pl
#
# You are allowed to use these materials for all purposes as long as the credit is given.

# %% [markdown]
# # Laboratory 4 - Neural Netoworks Training - Supervised

# %% [markdown]
# The goal of the Laboratory 4 is to:
# <ul>
#   <li> Familarize yourself with the gradient descent algorithm.
#   <li> Get familiar with the neural network training process.
#   <li> Train a neural network for the classification of brain tumors in the MRI images.
#   <li> Understand the training hyperparameters: batch size, number of epochs, learning rate.
# </ul>
#
# You are going to: (i) implement the gradient descent algorithm in PyTorch, (ii) implement a simple convolutional network architecture, (iii) train the neural network using the supervised strategy (for image classification).

# %% [markdown]
# ### Part I - Gradient Descent

# %% [markdown]
# The first part of the laboratory is not directly connected with the neural network training process but it is useful to understand the general concept.
#
# You will start by implementing a simple version of the gradient descent algorithm. You can build the intuition by reading:
#
# http://mlwiki.org/index.php/Gradient_Descent
#
# The gradient algorithm is the predecessor of the state-of-the-art optimization methods used to train the deep neural network like SGD or Adam - the methods you will use in the next parts of the laboratory. It is a first order gradient-based optimization method.
#
# Let's start by generating a simple function. Your task will be to find the minimum of the function by the gradient descent (using PyTorch).

# %%
import numpy as np
import torch as tc
import matplotlib.pyplot as plt

# Let f(x, y) = x**2 + y**2
# Let's minimize the function analytically
# Gf(x) = [df(x, y) / dx, df(x, y) / dy] = [2*x, 2*y]
# 2*x = 0
# 2*y = 0
# The minimum is clearly defined (x, y) = (0, 0)
# Now verify this by the gradient descent

# %%
# Implement the gradient descent here
def gradient_descent(f, initial_guess, num_iters, learning_rate, echo=False):
  """
  f - function (callable) : function taking N variables as input
  num_iters - int : number of iterations
  initial_guess - Tensor : vector of N variables
  learning_rate - float: the learning rate for the gradient descent update
  echo - bool: whether to print the results during each iteration
  Note: Implement the gradient calculation on your own
  """
  result = None # TODO - intialize the result
  step = 0.001 # Some inner step inside the function to calculate the gradient
  for i in range(num_iters):
    gradient = None # TODO - calculate the numerical gradient for each iteration
    result = None # TODO - update the arguments using the gradient descent equation
    if echo: # TODO - print the current result and the function value for this result
      pass # TODO
  return result

# %% [markdown]
# Now let's verify the implementation:

# %%
f = lambda x, y: x**2 + y**2
initial_guess = tc.randn(2).type(tc.float32) # Let's start with some two random numbers
num_iters = 50
learning_rate = 0.1
echo = True

result = gradient_descent(f, initial_guess, num_iters, learning_rate, echo)
print(f"Initial arguments: {initial_guess}, Value of the function for the initial arguments: {f(*initial_guess)}")
print(f"Result: {result}, Value of the function at the result: {f(*result)}")
# Out:
# Current result: tensor([0.0995, 1.0289]), Value of the function at the current result: 1.0685631036758423
# Current result: tensor([0.0795, 0.8230]), Value of the function at the current result: 0.6836931705474854
# Current result: tensor([0.0635, 0.6583]), Value of the function at the current result: 0.43741777539253235
# Current result: tensor([0.0507, 0.5266]), Value of the function at the current result: 0.2798331081867218
# Current result: tensor([0.0405, 0.4211]), Value of the function at the current result: 0.17900341749191284
# Current result: tensor([0.0323, 0.3368]), Value of the function at the current result: 0.11448987573385239
# Current result: tensor([0.0257, 0.2694]), Value of the function at the current result: 0.07321514934301376
# Current result: tensor([0.0205, 0.2154]), Value of the function at the current result: 0.04681093245744705
# Current result: tensor([0.0163, 0.1722]), Value of the function at the current result: 0.02992131933569908
# Current result: tensor([0.0129, 0.1377]), Value of the function at the current result: 0.01911948062479496
# Current result: tensor([0.0102, 0.1100]), Value of the function at the current result: 0.012212367728352547
# Current result: tensor([0.0081, 0.0879]), Value of the function at the current result: 0.0077966912649571896
# Current result: tensor([0.0064, 0.0702]), Value of the function at the current result: 0.004974532872438431
# Current result: tensor([0.0050, 0.0561]), Value of the function at the current result: 0.0031714588403701782
# Current result: tensor([0.0039, 0.0448]), Value of the function at the current result: 0.0020199811551719904
# Current result: tensor([0.0030, 0.0357]), Value of the function at the current result: 0.001285021542571485
# Current result: tensor([0.0023, 0.0285]), Value of the function at the current result: 0.00081623625010252
# Current result: tensor([0.0018, 0.0227]), Value of the function at the current result: 0.0005174846155568957
# Current result: tensor([0.0013, 0.0180]), Value of the function at the current result: 0.000327300833305344
# Current result: tensor([0.0009, 0.0143]), Value of the function at the current result: 0.00020639707508962601
# Current result: tensor([0.0007, 0.0114]), Value of the function at the current result: 0.0001296697446377948
# Current result: tensor([0.0004, 0.0090]), Value of the function at the current result: 8.108511246973649e-05
# Current result: tensor([0.0002, 0.0071]), Value of the function at the current result: 5.0407670642016456e-05
# Current result: tensor([9.0510e-05, 5.5767e-03]), Value of the function at the current result: 3.110748002654873e-05
# Current result: tensor([-2.7592e-05,  4.3613e-03]), Value of the function at the current result: 1.9022034393856302e-05
# Current result: tensor([-0.0001,  0.0034]), Value of the function at the current result: 1.150070056610275e-05
# Current result: tensor([-0.0002,  0.0026]), Value of the function at the current result: 6.85772920405725e-06
# Current result: tensor([-0.0003,  0.0020]), Value of the function at the current result: 4.02277100874926e-06
# Current result: tensor([-0.0003,  0.0015]), Value of the function at the current result: 2.3176323793450138e-06
# Current result: tensor([-0.0003,  0.0011]), Value of the function at the current result: 1.313732354901731e-06
# Current result: tensor([-0.0004,  0.0008]), Value of the function at the current result: 7.411468914142461e-07
# Current result: tensor([-0.0004,  0.0005]), Value of the function at the current result: 4.3062044596808846e-07
# Current result: tensor([-0.0004,  0.0003]), Value of the function at the current result: 2.7662628099278663e-07
# Current result: tensor([-0.0004,  0.0002]), Value of the function at the current result: 2.1386418325164414e-07
# Current result: tensor([-4.4928e-04,  2.1982e-05]), Value of the function at the current result: 2.023317762223087e-07
# Current result: tensor([-4.5942e-04, -8.2414e-05]), Value of the function at the current result: 2.178593092594383e-07
# Current result: tensor([-0.0005, -0.0002]), Value of the function at the current result: 2.4612353399788844e-07
# Current result: tensor([-0.0005, -0.0002]), Value of the function at the current result: 2.7887392661796184e-07
# Current result: tensor([-0.0005, -0.0003]), Value of the function at the current result: 3.1156321256275987e-07
# Current result: tensor([-0.0005, -0.0003]), Value of the function at the current result: 3.418675476041244e-07
# Current result: tensor([-0.0005, -0.0004]), Value of the function at the current result: 3.687688945319678e-07
# Current result: tensor([-0.0005, -0.0004]), Value of the function at the current result: 3.9199107959575485e-07
# Current result: tensor([-0.0005, -0.0004]), Value of the function at the current result: 4.116574530144135e-07
# Current result: tensor([-0.0005, -0.0004]), Value of the function at the current result: 4.2808733269339427e-07
# Current result: tensor([-0.0005, -0.0004]), Value of the function at the current result: 4.416771162141231e-07
# Current result: tensor([-0.0005, -0.0005]), Value of the function at the current result: 4.528343708898319e-07
# Current result: tensor([-0.0005, -0.0005]), Value of the function at the current result: 4.619427897978312e-07
# Current result: tensor([-0.0005, -0.0005]), Value of the function at the current result: 4.6934644615248544e-07
# Current result: tensor([-0.0005, -0.0005]), Value of the function at the current result: 4.753441658067459e-07
# Current result: tensor([-0.0005, -0.0005]), Value of the function at the current result: 4.801902377948863e-07
# Initial arguments: tensor([0.1246, 1.2863]), Value of the function for the initial arguments: 1.6700351238250732
# Result: tensor([-0.0005, -0.0005]), Value of the function at the result: 4.801902377948863e-07

# %% [markdown]
# You can observe that the function became a bit unstable during the last iterations. This is connected with the learning rate: (i) if the learning rate is too high the function can become unstable, (ii) if the learning rate is too low the time required for optimization will be longer.
#
# Verify the effect of the learning rate:

# %%
initial_guess = tc.randn(2).type(tc.float32) # Let's start with some two random numbers
num_iters = 50
learning_rate_low = 0.01
learning_rate_medium = 0.1
learning_rate_high =  10
echo = True

print()
result_lr_low = gradient_descent(f, initial_guess, num_iters, learning_rate_low, echo)
print()
print(f"Result: {result}, Value of the function at the result: {f(*result_lr_low)}")

print()
result_lr_medium = gradient_descent(f, initial_guess, num_iters, learning_rate_medium, echo)
print()
print(f"Result: {result}, Value of the function at the result: {f(*result_lr_medium)}")

print()
result_lr_high = gradient_descent(f, initial_guess, num_iters, learning_rate_high, echo)
print()
print(f"Result: {result}, Value of the function at the result: {f(*result_lr_high)}")
# Out:
# Current result: tensor([-0.1089,  2.0759]), Value of the function at the current result: 4.321132659912109
# Current result: tensor([-0.1068,  2.0344]), Value of the function at the current result: 4.149996757507324
# Current result: tensor([-0.1047,  1.9937]), Value of the function at the current result: 3.9856340885162354
# Current result: tensor([-0.1026,  1.9538]), Value of the function at the current result: 3.827758550643921
# Current result: tensor([-0.1005,  1.9147]), Value of the function at the current result: 3.6761302947998047
# Current result: tensor([-0.0985,  1.8764]), Value of the function at the current result: 3.530517816543579
# Current result: tensor([-0.0966,  1.8388]), Value of the function at the current result: 3.390669584274292
# Current result: tensor([-0.0946,  1.8021]), Value of the function at the current result: 3.2563607692718506
# Current result: tensor([-0.0928,  1.7660]), Value of the function at the current result: 3.127366304397583
# Current result: tensor([-0.0909,  1.7307]), Value of the function at the current result: 3.0034773349761963
# Current result: tensor([-0.0891,  1.6960]), Value of the function at the current result: 2.8844997882843018
# Current result: tensor([-0.0873,  1.6621]), Value of the function at the current result: 2.7702393531799316
# Current result: tensor([-0.0856,  1.6289]), Value of the function at the current result: 2.6605069637298584
# Current result: tensor([-0.0839,  1.5963]), Value of the function at the current result: 2.5551140308380127
# Current result: tensor([-0.0822,  1.5643]), Value of the function at the current result: 2.4538991451263428
# Current result: tensor([-0.0806,  1.5330]), Value of the function at the current result: 2.356693744659424
# Current result: tensor([-0.0790,  1.5024]), Value of the function at the current result: 2.2633347511291504
# Current result: tensor([-0.0774,  1.4723]), Value of the function at the current result: 2.173671245574951
# Current result: tensor([-0.0759,  1.4428]), Value of the function at the current result: 2.087564468383789
# Current result: tensor([-0.0744,  1.4140]), Value of the function at the current result: 2.0048680305480957
# Current result: tensor([-0.0729,  1.3857]), Value of the function at the current result: 1.9254456758499146
# Current result: tensor([-0.0715,  1.3580]), Value of the function at the current result: 1.849170207977295
# Current result: tensor([-0.0700,  1.3308]), Value of the function at the current result: 1.775915503501892
# Current result: tensor([-0.0686,  1.3042]), Value of the function at the current result: 1.7055593729019165
# Current result: tensor([-0.0673,  1.2781]), Value of the function at the current result: 1.6379910707473755
# Current result: tensor([-0.0659,  1.2525]), Value of the function at the current result: 1.5730992555618286
# Current result: tensor([-0.0646,  1.2274]), Value of the function at the current result: 1.5107779502868652
# Current result: tensor([-0.0634,  1.2029]), Value of the function at the current result: 1.4509265422821045
# Current result: tensor([-0.0621,  1.1788]), Value of the function at the current result: 1.393445372581482
# Current result: tensor([-0.0609,  1.1552]), Value of the function at the current result: 1.338239073753357
# Current result: tensor([-0.0597,  1.1321]), Value of the function at the current result: 1.2852226495742798
# Current result: tensor([-0.0585,  1.1095]), Value of the function at the current result: 1.2343041896820068
# Current result: tensor([-0.0573,  1.0873]), Value of the function at the current result: 1.1854050159454346
# Current result: tensor([-0.0562,  1.0655]), Value of the function at the current result: 1.1384414434432983
# Current result: tensor([-0.0551,  1.0442]), Value of the function at the current result: 1.093338131904602
# Current result: tensor([-0.0540,  1.0233]), Value of the function at the current result: 1.0500195026397705
# Current result: tensor([-0.0529,  1.0028]), Value of the function at the current result: 1.0084178447723389
# Current result: tensor([-0.0519,  0.9827]), Value of the function at the current result: 0.9684652090072632
# Current result: tensor([-0.0508,  0.9631]), Value of the function at the current result: 0.9300968647003174
# Current result: tensor([-0.0498,  0.9438]), Value of the function at the current result: 0.8932474851608276
# Current result: tensor([-0.0488,  0.9249]), Value of the function at the current result: 0.8578579425811768
# Current result: tensor([-0.0479,  0.9064]), Value of the function at the current result: 0.8238694667816162
# Current result: tensor([-0.0469,  0.8883]), Value of the function at the current result: 0.7912282943725586
# Current result: tensor([-0.0460,  0.8705]), Value of the function at the current result: 0.7598794102668762
# Current result: tensor([-0.0451,  0.8531]), Value of the function at the current result: 0.7297719120979309
# Current result: tensor([-0.0442,  0.8360]), Value of the function at the current result: 0.7008573412895203
# Current result: tensor([-0.0433,  0.8193]), Value of the function at the current result: 0.6730883121490479
# Current result: tensor([-0.0425,  0.8029]), Value of the function at the current result: 0.6464189887046814
# Current result: tensor([-0.0416,  0.7868]), Value of the function at the current result: 0.6208067536354065
# Current result: tensor([-0.0408,  0.7711]), Value of the function at the current result: 0.5962080359458923
#
# Result: tensor([-0.0005, -0.0005]), Value of the function at the result: 0.5962080359458923
#
# Current result: tensor([-0.0890,  1.6945]), Value of the function at the current result: 2.879361629486084
# Current result: tensor([-0.0713,  1.3555]), Value of the function at the current result: 1.8425335884094238
# Current result: tensor([-0.0572,  1.0843]), Value of the function at the current result: 1.178998589515686
# Current result: tensor([-0.0458,  0.8673]), Value of the function at the current result: 0.7543761134147644
# Current result: tensor([-0.0368,  0.6938]), Value of the function at the current result: 0.4826756417751312
# Current result: tensor([-0.0295,  0.5549]), Value of the function at the current result: 0.30881062150001526
# Current result: tensor([-0.0237,  0.4438]), Value of the function at the current result: 0.19755689799785614
# Current result: tensor([-0.0191,  0.3550]), Value of the function at the current result: 0.1263696253299713
# Current result: tensor([-0.0154,  0.2839]), Value of the function at the current result: 0.08082348853349686
# Current result: tensor([-0.0124,  0.2270]), Value of the function at the current result: 0.05168427154421806
# Current result: tensor([-0.0100,  0.1815]), Value of the function at the current result: 0.03304365277290344
# Current result: tensor([-0.0081,  0.1451]), Value of the function at the current result: 0.021120546385645866
# Current result: tensor([-0.0066,  0.1160]), Value of the function at the current result: 0.013495243154466152
# Current result: tensor([-0.0054,  0.0927]), Value of the function at the current result: 0.008619464002549648
# Current result: tensor([-0.0044,  0.0740]), Value of the function at the current result: 0.005502502899616957
# Current result: tensor([-0.0036,  0.0591]), Value of the function at the current result: 0.0035104744601994753
# Current result: tensor([-0.0030,  0.0472]), Value of the function at the current result: 0.0022378412541002035
# Current result: tensor([-0.0025,  0.0377]), Value of the function at the current result: 0.0014251647517085075
# Current result: tensor([-0.0021,  0.0300]), Value of the function at the current result: 0.0009064981713891029
# Current result: tensor([-0.0018,  0.0239]), Value of the function at the current result: 0.000575708516407758
# Current result: tensor([-0.0015,  0.0190]), Value of the function at the current result: 0.00036492905928753316
# Current result: tensor([-0.0013,  0.0151]), Value of the function at the current result: 0.00023077116929925978
# Current result: tensor([-0.0012,  0.0120]), Value of the function at the current result: 0.00014550276682712138
# Current result: tensor([-0.0010,  0.0095]), Value of the function at the current result: 9.140517067862675e-05
# Current result: tensor([-0.0009,  0.0075]), Value of the function at the current result: 5.7162036682711914e-05
# Current result: tensor([-0.0008,  0.0059]), Value of the function at the current result: 3.5549885069485754e-05
# Current result: tensor([-0.0008,  0.0046]), Value of the function at the current result: 2.196087189076934e-05
# Current result: tensor([-0.0007,  0.0036]), Value of the function at the current result: 1.3458113244269043e-05
# Current result: tensor([-0.0007,  0.0028]), Value of the function at the current result: 8.171719855454285e-06
# Current result: tensor([-0.0006,  0.0021]), Value of the function at the current result: 4.912720214633737e-06
# Current result: tensor([-0.0006,  0.0016]), Value of the function at the current result: 2.926397428382188e-06
# Current result: tensor([-0.0006,  0.0012]), Value of the function at the current result: 1.7346994809486205e-06
# Current result: tensor([-0.0006,  0.0008]), Value of the function at the current result: 1.0356518487242283e-06
# Current result: tensor([-0.0006,  0.0006]), Value of the function at the current result: 6.391726401488995e-07
# Current result: tensor([-0.0005,  0.0004]), Value of the function at the current result: 4.261547701389645e-07
# Current result: tensor([-0.0005,  0.0002]), Value of the function at the current result: 3.224065778795193e-07
# Current result: tensor([-5.2874e-04,  5.0071e-05]), Value of the function at the current result: 2.8207421109982533e-07
# Current result: tensor([-5.2299e-04, -5.9943e-05]), Value of the function at the current result: 2.7711473649105756e-07
# Current result: tensor([-0.0005, -0.0001]), Value of the function at the current result: 2.9062317707939656e-07
# Current result: tensor([-0.0005, -0.0002]), Value of the function at the current result: 3.1261467370313767e-07
# Current result: tensor([-0.0005, -0.0003]), Value of the function at the current result: 3.3736606042111816e-07
# Current result: tensor([-0.0005, -0.0003]), Value of the function at the current result: 3.617484480855637e-07
# Current result: tensor([-0.0005, -0.0004]), Value of the function at the current result: 3.841862792341999e-07
# Current result: tensor([-0.0005, -0.0004]), Value of the function at the current result: 4.040130647808837e-07
# Current result: tensor([-0.0005, -0.0004]), Value of the function at the current result: 4.2107544118152873e-07
# Current result: tensor([-0.0005, -0.0004]), Value of the function at the current result: 4.3549391648411984e-07
# Current result: tensor([-0.0005, -0.0004]), Value of the function at the current result: 4.47520676516433e-07
# Current result: tensor([-0.0005, -0.0005]), Value of the function at the current result: 4.574568492898834e-07
# Current result: tensor([-0.0005, -0.0005]), Value of the function at the current result: 4.656072860598215e-07
# Current result: tensor([-0.0005, -0.0005]), Value of the function at the current result: 4.7225660182448337e-07
#
# Result: tensor([-0.0005, -0.0005]), Value of the function at the result: 4.7225660182448337e-07
#
# Current result: tensor([  2.1014, -40.2535]), Value of the function at the current result: 1624.7601318359375
# Current result: tensor([-39.4025, 764.1898]), Value of the function at the current result: 585538.625
# Current result: tensor([   585.5974, -14235.8096]), Value of the function at the current result: 203001200.0
# Current result: tensor([   585.5974, 305764.1562]), Value of the function at the current result: 93492060160.0
# Current result: tensor([   585.5974, 305764.1562]), Value of the function at the current result: 93492060160.0
# Current result: tensor([   585.5974, 305764.1562]), Value of the function at the current result: 93492060160.0
# Current result: tensor([   585.5974, 305764.1562]), Value of the function at the current result: 93492060160.0
# Current result: tensor([   585.5974, 305764.1562]), Value of the function at the current result: 93492060160.0
# Current result: tensor([   585.5974, 305764.1562]), Value of the function at the current result: 93492060160.0
# Current result: tensor([   585.5974, 305764.1562]), Value of the function at the current result: 93492060160.0
# Current result: tensor([   585.5974, 305764.1562]), Value of the function at the current result: 93492060160.0
# Current result: tensor([   585.5974, 305764.1562]), Value of the function at the current result: 93492060160.0
# Current result: tensor([   585.5974, 305764.1562]), Value of the function at the current result: 93492060160.0
# Current result: tensor([   585.5974, 305764.1562]), Value of the function at the current result: 93492060160.0
# Current result: tensor([   585.5974, 305764.1562]), Value of the function at the current result: 93492060160.0
# Current result: tensor([   585.5974, 305764.1562]), Value of the function at the current result: 93492060160.0
# Current result: tensor([   585.5974, 305764.1562]), Value of the function at the current result: 93492060160.0
# Current result: tensor([   585.5974, 305764.1562]), Value of the function at the current result: 93492060160.0
# Current result: tensor([   585.5974, 305764.1562]), Value of the function at the current result: 93492060160.0
# Current result: tensor([   585.5974, 305764.1562]), Value of the function at the current result: 93492060160.0
# Current result: tensor([   585.5974, 305764.1562]), Value of the function at the current result: 93492060160.0
# Current result: tensor([   585.5974, 305764.1562]), Value of the function at the current result: 93492060160.0
# Current result: tensor([   585.5974, 305764.1562]), Value of the function at the current result: 93492060160.0
# Current result: tensor([   585.5974, 305764.1562]), Value of the function at the current result: 93492060160.0
# Current result: tensor([   585.5974, 305764.1562]), Value of the function at the current result: 93492060160.0
# Current result: tensor([   585.5974, 305764.1562]), Value of the function at the current result: 93492060160.0
# Current result: tensor([   585.5974, 305764.1562]), Value of the function at the current result: 93492060160.0
# Current result: tensor([   585.5974, 305764.1562]), Value of the function at the current result: 93492060160.0
# Current result: tensor([   585.5974, 305764.1562]), Value of the function at the current result: 93492060160.0
# Current result: tensor([   585.5974, 305764.1562]), Value of the function at the current result: 93492060160.0
# Current result: tensor([   585.5974, 305764.1562]), Value of the function at the current result: 93492060160.0
# Current result: tensor([   585.5974, 305764.1562]), Value of the function at the current result: 93492060160.0
# Current result: tensor([   585.5974, 305764.1562]), Value of the function at the current result: 93492060160.0
# Current result: tensor([   585.5974, 305764.1562]), Value of the function at the current result: 93492060160.0
# Current result: tensor([   585.5974, 305764.1562]), Value of the function at the current result: 93492060160.0
# Current result: tensor([   585.5974, 305764.1562]), Value of the function at the current result: 93492060160.0
# Current result: tensor([   585.5974, 305764.1562]), Value of the function at the current result: 93492060160.0
# Current result: tensor([   585.5974, 305764.1562]), Value of the function at the current result: 93492060160.0
# Current result: tensor([   585.5974, 305764.1562]), Value of the function at the current result: 93492060160.0
# Current result: tensor([   585.5974, 305764.1562]), Value of the function at the current result: 93492060160.0
# Current result: tensor([   585.5974, 305764.1562]), Value of the function at the current result: 93492060160.0
# Current result: tensor([   585.5974, 305764.1562]), Value of the function at the current result: 93492060160.0
# Current result: tensor([   585.5974, 305764.1562]), Value of the function at the current result: 93492060160.0
# Current result: tensor([   585.5974, 305764.1562]), Value of the function at the current result: 93492060160.0
# Current result: tensor([   585.5974, 305764.1562]), Value of the function at the current result: 93492060160.0
# Current result: tensor([   585.5974, 305764.1562]), Value of the function at the current result: 93492060160.0
# Current result: tensor([   585.5974, 305764.1562]), Value of the function at the current result: 93492060160.0
# Current result: tensor([   585.5974, 305764.1562]), Value of the function at the current result: 93492060160.0
# Current result: tensor([   585.5974, 305764.1562]), Value of the function at the current result: 93492060160.0
# Current result: tensor([   585.5974, 305764.1562]), Value of the function at the current result: 93492060160.0
#
# Result: tensor([-0.0005, -0.0005]), Value of the function at the result: 93492060160.0

# %% [markdown]
# You can observe that for the low learning rate the function requires more iterations to converge, the medium learning rate is more or less acceptable, while the high learning rate led to an unstability during the training process.
#
# Next, let's implement the gradient descent again, however, this time use the PyTorch Autograd to calculate the gradient.
#
# You may find useful to first read:
#
# https://pytorch.org/tutorials/beginner/blitz/autograd_tutorial.html

# %%
# Implement the gradient descent here
def gradient_descent_autograd(f, initial_guess, num_iters, learning_rate, echo=False):
  """
  f - function (callable) :of N variables
  num_iters - int : number of iterations
  initial_guess - Tensor : vector of N variables
  learning_rate - float: the learning rate for gradient descent update
  echo - bool: whether to print the results during each iteration
  Note: Implement the gradient calculation using PyTorch Autograd
  """
  result = None # TODO - intialize the result
  for i in range(num_iters):
    # TODO - calculate the gradient using Autograd
    gradient = None
    # TODO - update the result using the gradient descent equation
    result = None # update the arguments using the gradient descent equation
    if echo: # TODO - print the current result and the function value for this result
      pass # TODO
    # TODO - reset the gradient for result
  return result

# %% [markdown]
# Verify the correctness. Moreover, compare the running time with the previously implemented function (with echo = False).

# %%
initial_guess = tc.randn(2).type(tc.float32)# Let's start with some two random numbers
num_iters = 50
learning_rate = 0.1
echo = True

result = gradient_descent(f, initial_guess, num_iters, learning_rate, echo)
result_autograd = gradient_descent_autograd(f, initial_guess, num_iters, learning_rate, echo)
print(f"Initial arguments: {initial_guess}, Value of the function for the initial arguments: {f(*initial_guess)}")
print(f"Result: {result}, Value of the function at the result: {f(*result)}")
print(f"Result Autograd: {result_autograd}, Value of the function at the result: {f(*result_autograd)}")

print()
# TODO - measure the execution time - note this is a toy problem and the autograd is calculated using GPU
# Out:
# Current result: tensor([ 0.3732, -0.7015]), Value of the function at the current result: 0.6314293742179871
# Current result: tensor([ 0.2985, -0.5613]), Value of the function at the current result: 0.40417346358299255
# Current result: tensor([ 0.2387, -0.4492]), Value of the function at the current result: 0.25871512293815613
# Current result: tensor([ 0.1909, -0.3594]), Value of the function at the current result: 0.16561084985733032
# Current result: tensor([ 0.1526, -0.2876]), Value of the function at the current result: 0.10601793229579926
# Current result: tensor([ 0.1220, -0.2302]), Value of the function at the current result: 0.06787353754043579
# Current result: tensor([ 0.0975, -0.1843]), Value of the function at the current result: 0.04345656558871269
# Current result: tensor([ 0.0779, -0.1475]), Value of the function at the current result: 0.027825977653265
# Current result: tensor([ 0.0622, -0.1181]), Value of the function at the current result: 0.017819834873080254
# Current result: tensor([ 0.0497, -0.0946]), Value of the function at the current result: 0.01141364499926567
# Current result: tensor([ 0.0396, -0.0758]), Value of the function at the current result: 0.007311924826353788
# Current result: tensor([ 0.0316, -0.0607]), Value of the function at the current result: 0.004685425665229559
# Current result: tensor([ 0.0252, -0.0487]), Value of the function at the current result: 0.0030033544171601534
# Current result: tensor([ 0.0200, -0.0390]), Value of the function at the current result: 0.0019259271211922169
# Current result: tensor([ 0.0159, -0.0313]), Value of the function at the current result: 0.0012356534134596586
# Current result: tensor([ 0.0127, -0.0252]), Value of the function at the current result: 0.0007933007436804473
# Current result: tensor([ 0.0100, -0.0202]), Value of the function at the current result: 0.000509734614752233
# Current result: tensor([ 0.0079, -0.0163]), Value of the function at the current result: 0.00032788404496386647
# Current result: tensor([ 0.0062, -0.0131]), Value of the function at the current result: 0.00021120489691384137
# Current result: tensor([ 0.0049, -0.0106]), Value of the function at the current result: 0.00013629443128593266
# Current result: tensor([ 0.0038, -0.0086]), Value of the function at the current result: 8.816305489744991e-05
# Current result: tensor([ 0.0029, -0.0070]), Value of the function at the current result: 5.720806439057924e-05
# Current result: tensor([ 0.0023, -0.0057]), Value of the function at the current result: 3.7276120565366e-05
# Current result: tensor([ 0.0017, -0.0046]), Value of the function at the current result: 2.4423077775281854e-05
# Current result: tensor([ 0.0013, -0.0038]), Value of the function at the current result: 1.6119865904329345e-05
# Current result: tensor([ 0.0009, -0.0031]), Value of the function at the current result: 1.074398824130185e-05
# Current result: tensor([ 0.0006, -0.0026]), Value of the function at the current result: 7.253973308252171e-06
# Current result: tensor([ 0.0004, -0.0022]), Value of the function at the current result: 4.980799985787598e-06
# Current result: tensor([ 0.0002, -0.0019]), Value of the function at the current result: 3.4943166156153893e-06
# Current result: tensor([ 7.8353e-05, -1.5848e-03]), Value of the function at the current result: 2.517646862543188e-06
# Current result: tensor([-3.7318e-05, -1.3678e-03]), Value of the function at the current result: 1.8723211496762815e-06
# Current result: tensor([-0.0001, -0.0012]), Value of the function at the current result: 1.4431075214815792e-06
# Current result: tensor([-0.0002, -0.0011]), Value of the function at the current result: 1.1554463981156005e-06
# Current result: tensor([-0.0003, -0.0009]), Value of the function at the current result: 9.609717608327628e-07
# Current result: tensor([-0.0003, -0.0009]), Value of the function at the current result: 8.282106023216329e-07
# Current result: tensor([-0.0003, -0.0008]), Value of the function at the current result: 7.366058980551315e-07
# Current result: tensor([-0.0004, -0.0007]), Value of the function at the current result: 6.726686478941701e-07
# Current result: tensor([-0.0004, -0.0007]), Value of the function at the current result: 6.275006398936966e-07
# Current result: tensor([-0.0004, -0.0006]), Value of the function at the current result: 5.951945354354393e-07
# Current result: tensor([-0.0004, -0.0006]), Value of the function at the current result: 5.717997737519909e-07
# Current result: tensor([-0.0005, -0.0006]), Value of the function at the current result: 5.546521038013452e-07
# Current result: tensor([-0.0005, -0.0006]), Value of the function at the current result: 5.419375384008163e-07
# Current result: tensor([-0.0005, -0.0006]), Value of the function at the current result: 5.324081371327338e-07
# Current result: tensor([-0.0005, -0.0005]), Value of the function at the current result: 5.251957304608368e-07
# Current result: tensor([-0.0005, -0.0005]), Value of the function at the current result: 5.196889105718583e-07
# Current result: tensor([-0.0005, -0.0005]), Value of the function at the current result: 5.154518021299737e-07
# Current result: tensor([-0.0005, -0.0005]), Value of the function at the current result: 5.12169890498626e-07
# Current result: tensor([-0.0005, -0.0005]), Value of the function at the current result: 5.096133008919423e-07
# Current result: tensor([-0.0005, -0.0005]), Value of the function at the current result: 5.076121851743665e-07
# Current result: tensor([-0.0005, -0.0005]), Value of the function at the current result: 5.060395551481633e-07
# Current result: tensor([ 0.3733, -0.7014], grad_fn=<SubBackward0>), Value of the function at the current result: 0.6313601732254028
# Current result: tensor([ 0.2987, -0.5611], grad_fn=<SubBackward0>), Value of the function at the current result: 0.40407055616378784
# Current result: tensor([ 0.2389, -0.4489], grad_fn=<SubBackward0>), Value of the function at the current result: 0.25860512256622314
# Current result: tensor([ 0.1912, -0.3591], grad_fn=<SubBackward0>), Value of the function at the current result: 0.16550728678703308
# Current result: tensor([ 0.1529, -0.2873], grad_fn=<SubBackward0>), Value of the function at the current result: 0.10592466592788696
# Current result: tensor([ 0.1223, -0.2298], grad_fn=<SubBackward0>), Value of the function at the current result: 0.06779178977012634
# Current result: tensor([ 0.0979, -0.1839], grad_fn=<SubBackward0>), Value of the function at the current result: 0.04338674992322922
# Current result: tensor([ 0.0783, -0.1471], grad_fn=<SubBackward0>), Value of the function at the current result: 0.027767518535256386
# Current result: tensor([ 0.0626, -0.1177], grad_fn=<SubBackward0>), Value of the function at the current result: 0.01777121052145958
# Current result: tensor([ 0.0501, -0.0941], grad_fn=<SubBackward0>), Value of the function at the current result: 0.01137357484549284
# Current result: tensor([ 0.0401, -0.0753], grad_fn=<SubBackward0>), Value of the function at the current result: 0.007279088720679283
# Current result: tensor([ 0.0321, -0.0603], grad_fn=<SubBackward0>), Value of the function at the current result: 0.004658616613596678
# Current result: tensor([ 0.0257, -0.0482], grad_fn=<SubBackward0>), Value of the function at the current result: 0.0029815146699547768
# Current result: tensor([ 0.0205, -0.0386], grad_fn=<SubBackward0>), Value of the function at the current result: 0.0019081691280007362
# Current result: tensor([ 0.0164, -0.0308], grad_fn=<SubBackward0>), Value of the function at the current result: 0.0012212282745167613
# Current result: tensor([ 0.0131, -0.0247], grad_fn=<SubBackward0>), Value of the function at the current result: 0.0007815861026756465
# Current result: tensor([ 0.0105, -0.0197], grad_fn=<SubBackward0>), Value of the function at the current result: 0.0005002151010558009
# Current result: tensor([ 0.0084, -0.0158], grad_fn=<SubBackward0>), Value of the function at the current result: 0.0003201376530341804
# Current result: tensor([ 0.0067, -0.0126], grad_fn=<SubBackward0>), Value of the function at the current result: 0.00020488809968810529
# Current result: tensor([ 0.0054, -0.0101], grad_fn=<SubBackward0>), Value of the function at the current result: 0.00013112839951645583
# Current result: tensor([ 0.0043, -0.0081], grad_fn=<SubBackward0>), Value of the function at the current result: 8.392216841457412e-05
# Current result: tensor([ 0.0034, -0.0065], grad_fn=<SubBackward0>), Value of the function at the current result: 5.3710187785327435e-05
# Current result: tensor([ 0.0028, -0.0052], grad_fn=<SubBackward0>), Value of the function at the current result: 3.437451960053295e-05
# Current result: tensor([ 0.0022, -0.0041], grad_fn=<SubBackward0>), Value of the function at the current result: 2.1999690943630412e-05
# Current result: tensor([ 0.0018, -0.0033], grad_fn=<SubBackward0>), Value of the function at the current result: 1.4079802895139437e-05
# Current result: tensor([ 0.0014, -0.0026], grad_fn=<SubBackward0>), Value of the function at the current result: 9.011074325826485e-06
# Current result: tensor([ 0.0011, -0.0021], grad_fn=<SubBackward0>), Value of the function at the current result: 5.7670877140481025e-06
# Current result: tensor([ 0.0009, -0.0017], grad_fn=<SubBackward0>), Value of the function at the current result: 3.6909359550918452e-06
# Current result: tensor([ 0.0007, -0.0014], grad_fn=<SubBackward0>), Value of the function at the current result: 2.3621992113476153e-06
# Current result: tensor([ 0.0006, -0.0011], grad_fn=<SubBackward0>), Value of the function at the current result: 1.5118074543352122e-06
# Current result: tensor([ 0.0005, -0.0009], grad_fn=<SubBackward0>), Value of the function at the current result: 9.675567298472743e-07
# Current result: tensor([ 0.0004, -0.0007], grad_fn=<SubBackward0>), Value of the function at the current result: 6.192363457557803e-07
# Current result: tensor([ 0.0003, -0.0006], grad_fn=<SubBackward0>), Value of the function at the current result: 3.963112362725951e-07
# Current result: tensor([ 0.0002, -0.0004], grad_fn=<SubBackward0>), Value of the function at the current result: 2.536392003094079e-07
# Current result: tensor([ 0.0002, -0.0004], grad_fn=<SubBackward0>), Value of the function at the current result: 1.6232908706115268e-07
# Current result: tensor([ 0.0002, -0.0003], grad_fn=<SubBackward0>), Value of the function at the current result: 1.0389062055082832e-07
# Current result: tensor([ 0.0001, -0.0002], grad_fn=<SubBackward0>), Value of the function at the current result: 6.648999573144465e-08
# Current result: tensor([ 9.6926e-05, -1.8210e-04], grad_fn=<SubBackward0>), Value of the function at the current result: 4.2553594425953634e-08
# Current result: tensor([ 7.7541e-05, -1.4568e-04], grad_fn=<SubBackward0>), Value of the function at the current result: 2.723430370110691e-08
# Current result: tensor([ 6.2033e-05, -1.1654e-04], grad_fn=<SubBackward0>), Value of the function at the current result: 1.7429954368708422e-08
# Current result: tensor([ 4.9626e-05, -9.3233e-05], grad_fn=<SubBackward0>), Value of the function at the current result: 1.1155171009136211e-08
# Current result: tensor([ 3.9701e-05, -7.4586e-05], grad_fn=<SubBackward0>), Value of the function at the current result: 7.139309587955722e-09
# Current result: tensor([ 3.1761e-05, -5.9669e-05], grad_fn=<SubBackward0>), Value of the function at the current result: 4.56915794089241e-09
# Current result: tensor([ 2.5409e-05, -4.7735e-05], grad_fn=<SubBackward0>), Value of the function at the current result: 2.9242610555257897e-09
# Current result: tensor([ 2.0327e-05, -3.8188e-05], grad_fn=<SubBackward0>), Value of the function at the current result: 1.8715271554725632e-09
# Current result: tensor([ 1.6262e-05, -3.0551e-05], grad_fn=<SubBackward0>), Value of the function at the current result: 1.1977774327931456e-09
# Current result: tensor([ 1.3009e-05, -2.4440e-05], grad_fn=<SubBackward0>), Value of the function at the current result: 7.665775236809225e-10
# Current result: tensor([ 1.0407e-05, -1.9552e-05], grad_fn=<SubBackward0>), Value of the function at the current result: 4.906096084944522e-10
# Current result: tensor([ 8.3259e-06, -1.5642e-05], grad_fn=<SubBackward0>), Value of the function at the current result: 3.1399019495559344e-10
# Current result: tensor([ 6.6607e-06, -1.2514e-05], grad_fn=<SubBackward0>), Value of the function at the current result: 2.009536981262272e-10
# Initial arguments: tensor([ 0.4667, -0.8768]), Value of the function for the initial arguments: 0.9865003228187561
# Result: tensor([-0.0005, -0.0005]), Value of the function at the result: 5.060395551481633e-07
# Result Autograd: tensor([ 6.6607e-06, -1.2514e-05], requires_grad=True), Value of the function at the result: 2.009536981262272e-10
#
# 6.98 ms ± 1.29 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 5.06 ms ± 101 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# You can see that both the method work. However, the Autograd outputs more accurate results. The reason for this is connected with the fact that Autograd attempts to configure the gradient as accurately as possible (e.g. by choosing a dedicated gradient step). A speed-up compared with the naive gradient approximiation could be observed with more real-like problems (more variables) and using GPUs.

# %% [markdown]
# ### Part II - Convolutional Neural Network

# %% [markdown]
# Let's now implement a simple neural network. Following the knowledge and skills you gained during Laboratory 2.
#
# Implement a neural network with the following architecture:
#
# <ul>
#   <li> Conv2D with:
#     <ul>
#       <li> Input channels: 1
#       <li> Output channels: 32
#       <li> Kernel size: 3
#       <li> Stride : 1
#       <li> Padding: 1
#     </ul>
#   <li> BatchNorm2D
#   <li> ReLU activation function
#   <li> Conv2D with:
#     <ul>
#       <li> Input channels: 32
#       <li> Output channels: 64
#       <li> Kernel size: 3
#       <li> Stride : 2
#       <li> Padding: 2
#     </ul>
#   <li> BatchNorm2D
#   <li> ReLU activation function
#   <li> Conv2D with:
#     <ul>
#       <li> Input channels: 64
#       <li> Output channels: 64
#       <li> Kernel size: 3
#       <li> Stride : 1
#       <li> Padding: 1
#     </ul>
#   <li> BatchNorm2D
#   <li> ReLU activation function
#   <li> Conv2D with:
#     <ul>
#       <li> Input channels: 64
#       <li> Output channels: 64
#       <li> Kernel size: 3
#       <li> Stride : 2
#       <li> Padding: 2
#     </ul>
#   <li> BatchNorm2D
#   <li> ReLU activation function
#   <li> Conv2D with:
#     <ul>
#       <li> Input channels: 64
#       <li> Output channels: 64
#       <li> Kernel size: 3
#       <li> Stride : 2
#       <li> Padding: 2
#     </ul>
#   <li> BatchNorm2D
#   <li> ReLU activation function
#   <li> Conv2D with:
#     <ul>
#       <li> Input channels: 64
#       <li> Output channels: 64
#       <li> Kernel size: 3
#       <li> Stride : 2
#       <li> Padding: 1
#     </ul>
#   <li> BatchNorm2D
#   <li> ReLU activation function
#   <li> Adaptive Average Pooling to size (B, 128, 1, 1)
#   <li> Linear layer with input size: 64, and output size: 64
#   <li> ReLU activation function
#   <li> Linear layer with input size: 64 and output size: 64
#   <li> ReLU activation function
#   <li> Linear layer with input size: 64 and output size: 4
# </ul>

# %%
class ClassificationNetwork(tc.nn.Module):
    #TODO - implement the neural network architecture
    def __init__(self):
        super(ClassificationNetwork, self).__init__()
        # TODO

    def forward(self, x):
        # TODO - implement the forward pass
        pass

# %% [markdown]
# And generate random input to the verify whether the neural networks processes the input correctly:

# %%
from torchsummary import summary
device = "cuda:0"

classification_network = ClassificationNetwork()

batch_size = 4
random_input = tc.randn((batch_size, 1, 224, 224))
random_output = classification_network(random_input)

print(f"Size of the random input: {random_input.size()}")
print(f"Size of the random output: {random_output.size()}")
print("Random output: ")
print(random_output)

print("Network summary: ")
summary(classification_network.to(device), (1, 224, 224))
# Out:
# Size of the random input: torch.Size([4, 1, 224, 224])
# Size of the random output: torch.Size([4, 4])
# Random output:
# tensor([[-0.1029, -0.0702, -0.0925, -0.0952],
#         [-0.1074, -0.0718, -0.0927, -0.0939],
#         [-0.1038, -0.0687, -0.1003, -0.0948],
#         [-0.1010, -0.0723, -0.0978, -0.0968]], grad_fn=<AddmmBackward0>)
# Network summary:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 32, 224, 224]             320
#        BatchNorm2d-2         [-1, 32, 224, 224]              64
#               ReLU-3         [-1, 32, 224, 224]               0
#             Conv2d-4         [-1, 64, 113, 113]          18,496
#        BatchNorm2d-5         [-1, 64, 113, 113]             128
#               ReLU-6         [-1, 64, 113, 113]               0
#             Conv2d-7         [-1, 64, 113, 113]          36,928
#        BatchNorm2d-8         [-1, 64, 113, 113]             128
#               ReLU-9         [-1, 64, 113, 113]               0
#            Conv2d-10           [-1, 64, 58, 58]          36,928
#       BatchNorm2d-11           [-1, 64, 58, 58]             128
#              ReLU-12           [-1, 64, 58, 58]               0
#            Conv2d-13           [-1, 64, 30, 30]          36,928
#       BatchNorm2d-14           [-1, 64, 30, 30]             128
#              ReLU-15           [-1, 64, 30, 30]               0
#            Conv2d-16           [-1, 64, 16, 16]          36,928
#       BatchNorm2d-17           [-1, 64, 16, 16]             128
#              ReLU-18           [-1, 64, 16, 16]               0
# AdaptiveAvgPool2d-19             [-1, 64, 1, 1]               0
#            Linear-20                   [-1, 64]           4,160
#              ReLU-21                   [-1, 64]               0
#            Linear-22                   [-1, 64]           4,160
#              ReLU-23                   [-1, 64]               0
#            Linear-24                    [-1, 4]             260
# ================================================================
# Total params: 175,812
# Trainable params: 175,812
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.19
# Forward/backward pass size (MB): 80.78
# Params size (MB): 0.67
# Estimated Total Size (MB): 81.64
# ----------------------------------------------------------------

# %% [markdown]
# ### Part III - Dataset, Dataloader

# %% [markdown]
# You are going to use the dataset from the Laboratory 3 dedicated to tumor classification in the MRI images. Mount the google drives, create the pathes and copy-paste the dataloader (the extended version) to the cell below:

# %%
import os
import pandas as pd
# !pip install SimpleITK
import SimpleITK as sitk
import torchvision as tv

# TODO - use the dataloader from the previous laboratory
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: SimpleITK in /usr/local/lib/python3.7/dist-packages (2.2.0)
# Available classes: ['glioma_tumor', 'no_tumor', 'pituitary_tumor', 'meningioma_tumor']
# Classes dict: {'glioma_tumor': 0, 'no_tumor': 1, 'pituitary_tumor': 2, 'meningioma_tumor': 3}

# %% [markdown]
# Verify whether the data is being loaded correctly:

# %%
# TODO - create the visualization as below (previous laboratory)

# %% [markdown]
# ### Part IV - Network Training

# %% [markdown]
# Now it's the time to train the neural network. During this laboratory you are going to do this in a supervised manner. It means that the ground-truth labels will be provided during the training process to guide the network parameters into local minima of the objective function dedicated to image classification.
#
# This time you will analyze the training process in a simplified way by accumulating and visualizing the process using matplotlib. More advanced TensorBoard logging will be the task during the next Laboratory.
#
# Start with creating the training function.

# %%
def training(model, training_dataloader, testing_dataloader, training_params):
  num_epochs = training_params['num_epochs']
  learning_rate = training_params['learning_rate']

  objective_function = None # TODO: use the cross entropy loss (search for documentation)
  parameters = None # TODO: get the model parameters
  optimizer = None # TODO: use the Adam optimizer for the model parameters and the defined learning rate
  device = "cuda:0" # You want to use GPU (remember to set the correct run enviroment in the Google Colab settings)

  training_losses = []
  testing_losses = [] # NOTE: in practical applications you should use validation set
  model = model.to(device) # Transfer the network to GPU
  
  print(f"Training dataset size: {len(training_dataloader.dataset)}")
  print(f"Testing dataset size: {len(testing_dataloader.dataset)}")
  for epoch in range(num_epochs):
    print(f"Current epoch: {epoch}")

    training_epoch_loss = 0.0
    model.train()
    for images, classes in training_dataloader:
        images, classes = None # TODO: Transfer the images and classes to GPU
        output = None # TODO: Forward the images through the model
        loss = None # TODO: Calculate the objective function 
        # TODO: Backpropagate the gradient
        # TODO: Update the optimizer
        # TODO: Reset the optimizer gradient
        # TODO: Update the epoch loss

    training_epoch_loss = training_epoch_loss / len(training_dataloader.dataset)
    training_losses.append(training_epoch_loss)
    print(f"Current epoch training loss: {training_epoch_loss}")

    testing_epoch_loss = 0.0
    model.eval()
    for images, classes in testing_dataloader:
      with tc.set_grad_enabled(False):
        images, classes = None # TODO: Transfer the images and classes to GPU
        output = None # TODO: Forward the images through the model
        loss = None # TODO: Calculate the objective function 
        # TODO: Update the epoch loss

    testing_epoch_loss = testing_epoch_loss / len(testing_dataloader.dataset)
    testing_losses.append(testing_epoch_loss)
    print(f"Current epoch testing loss: {testing_epoch_loss}")

  # Return the trained model and the history of training and testing losses
  return model, training_losses, testing_losses

# %% [markdown]
# Now define the training hyperparameters and create the training/testing dataloader (note: during this laboratory you not have the validation dataloader and the testing set is used as the validation dataloader, it will be modified during the next Laboratory):

# %%
learning_rate = 0.003
batch_size = 32
num_epochs = 100
shuffle = True
model = ClassificationNetwork()

training_params = {
    'learning_rate': learning_rate,
    'num_epochs': num_epochs,
}

training_dataset = BrainDataset(os.path.join(dataset_path, "Training"), training_csv_path)
training_dataloader = tc.utils.data.DataLoader(training_dataset, batch_size=batch_size, shuffle=shuffle)

testing_dataset = BrainDataset(os.path.join(dataset_path, "Testing"), testing_csv_path)
testing_dataloader = tc.utils.data.DataLoader(testing_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# Run the training:

# %%
model, training_losses, testing_losses = training(model, training_dataloader, testing_dataloader, training_params)
# Out:
# Training dataset size: 2870
# Testing dataset size: 394
# Current epoch: 0
# Current epoch training loss: 1.191251747616492
# Current epoch testing loss: 1.3677289207574679
# Current epoch: 1
# Current epoch training loss: 1.0666334419715695
# Current epoch testing loss: 1.391054583079924
# Current epoch: 2
# Current epoch training loss: 1.0458968392647932
# Current epoch testing loss: 1.3970628970770667
# Current epoch: 3
# Current epoch training loss: 1.0321706358148661
# Current epoch testing loss: 1.3686306555259047
# Current epoch: 4
# Current epoch training loss: 1.0382755297817003
# Current epoch testing loss: 1.3272206226581245
# Current epoch: 5
# Current epoch training loss: 1.0222264204706464
# Current epoch testing loss: 1.3354661392076366
# Current epoch: 6
# Current epoch training loss: 1.0267852810617109
# Current epoch testing loss: 1.3777127054137022
# Current epoch: 7
# Current epoch training loss: 1.0156189266397562
# Current epoch testing loss: 1.4371633420740892
# Current epoch: 8
# Current epoch training loss: 1.0169275315796458
# Current epoch testing loss: 1.3252254101225567
# Current epoch: 9
# Current epoch training loss: 1.005908046616079
# Current epoch testing loss: 1.2850951216547621
# Current epoch: 10
# Current epoch training loss: 1.0031517069514204
# Current epoch testing loss: 1.323351864887373
# Current epoch: 11
# Current epoch training loss: 1.0088880078717806
# Current epoch testing loss: 1.3680374755472096
# Current epoch: 12
# Current epoch training loss: 1.0002432703556499
# Current epoch testing loss: 1.3977762067378474
# Current epoch: 13
# Current epoch training loss: 1.0002083426153203
# Current epoch testing loss: 1.2730820923287252
# Current epoch: 14
# Current epoch training loss: 0.9884585588235888
# Current epoch testing loss: 1.287949209890995
# Current epoch: 15
# Current epoch training loss: 0.9895784021669979
# Current epoch testing loss: 1.3205240765198838
# Current epoch: 16
# Current epoch training loss: 0.9865885688037407
# Current epoch testing loss: 1.2487985180114127
# Current epoch: 17
# Current epoch training loss: 0.9891620761426069
# Current epoch testing loss: 1.4026495992834798
# Current epoch: 18
# Current epoch training loss: 0.9836514585940265
# Current epoch testing loss: 1.25500493787872
# Current epoch: 19
# Current epoch training loss: 0.9792359951481171
# Current epoch testing loss: 1.2556381867016633
# Current epoch: 20
# Current epoch training loss: 0.970899227355
# Current epoch testing loss: 1.3037934853945892
# Current epoch: 21
# Current epoch training loss: 0.9808793604996977
# Current epoch testing loss: 1.2680105684977498
# Current epoch: 22
# Current epoch training loss: 0.972318487715638
# Current epoch testing loss: 1.278624423264247
# Current epoch: 23
# Current epoch training loss: 0.9686221805599093
# Current epoch testing loss: 1.2740661783266793
# Current epoch: 24
# Current epoch training loss: 0.9757540540412744
# Current epoch testing loss: 1.3783963591919333
# Current epoch: 25
# Current epoch training loss: 0.9737279541816446
# Current epoch testing loss: 1.2704953409088444
# Current epoch: 26
# Current epoch training loss: 0.9704518581516651
# Current epoch testing loss: 1.2525401424030362
# Current epoch: 27
# Current epoch training loss: 0.9685180070508232
# Current epoch testing loss: 1.2939000843745199
# Current epoch: 28
# Current epoch training loss: 0.9638857717713413
# Current epoch testing loss: 1.313475957981826
# Current epoch: 29
# Current epoch training loss: 0.9630414172747409
# Current epoch testing loss: 1.2742373422922821
# Current epoch: 30
# Current epoch training loss: 0.9708750926243719
# Current epoch testing loss: 1.3221672591824216
# Current epoch: 31
# Current epoch training loss: 0.962222862326725
# Current epoch testing loss: 1.2530130305266016
# Current epoch: 32
# Current epoch training loss: 0.9591365892712663
# Current epoch testing loss: 1.3822972707942052
# Current epoch: 33
# Current epoch training loss: 0.9608560560472336
# Current epoch testing loss: 1.2543902711819876
# Current epoch: 34
# Current epoch training loss: 0.9615402394470853
# Current epoch testing loss: 1.2741099735201917
# Current epoch: 35
# Current epoch training loss: 0.9617588548294759
# Current epoch testing loss: 1.296712649655221
# Current epoch: 36
# Current epoch training loss: 0.9578523330987538
# Current epoch testing loss: 1.2225200645814693
# Current epoch: 37
# Current epoch training loss: 0.9545719542985178
# Current epoch testing loss: 1.2998887300491333
# Current epoch: 38
# Current epoch training loss: 0.9569176770253464
# Current epoch testing loss: 1.2148462618668068
# Current epoch: 39
# Current epoch training loss: 0.9495278042367942
# Current epoch testing loss: 1.2415189743041992
# Current epoch: 40
# Current epoch training loss: 0.9680867159408144
# Current epoch testing loss: 1.2147627258058733
# Current epoch: 41
# Current epoch training loss: 0.9582837300018151
# Current epoch testing loss: 1.2726754004580116
# Current epoch: 42
# Current epoch training loss: 0.9485302321586875
# Current epoch testing loss: 1.2753689712679326
# Current epoch: 43
# Current epoch training loss: 0.9434966635205605
# Current epoch testing loss: 1.2918988738568302
# Current epoch: 44
# Current epoch training loss: 0.9419720751483266
# Current epoch testing loss: 1.22472491179626
# Current epoch: 45
# Current epoch training loss: 0.9523742450238936
# Current epoch testing loss: 1.25389536141139
# Current epoch: 46
# Current epoch training loss: 0.9508069701726428
# Current epoch testing loss: 1.2080029194730186
# Current epoch: 47
# Current epoch training loss: 0.9506924338041698
# Current epoch testing loss: 1.206051863994695
# Current epoch: 48
# Current epoch training loss: 0.9420346318637037
# Current epoch testing loss: 1.3235191330691884
# Current epoch: 49
# Current epoch training loss: 0.9408610630533837
# Current epoch testing loss: 1.3256186870148945
# Current epoch: 50
# Current epoch training loss: 0.9364350735102797
# Current epoch testing loss: 1.2230768088761925
# Current epoch: 51
# Current epoch training loss: 0.9423363913642405
# Current epoch testing loss: 1.2783863387132055
# Current epoch: 52
# Current epoch training loss: 0.9418668390566464
# Current epoch testing loss: 1.2202551540384439
# Current epoch: 53
# Current epoch training loss: 0.948347952515406
# Current epoch testing loss: 1.3431120390819413
# Current epoch: 54
# Current epoch training loss: 0.9445108998112562
# Current epoch testing loss: 1.1809494204932662
# Current epoch: 55
# Current epoch training loss: 0.9388570421248779
# Current epoch testing loss: 1.185658252178715
# Current epoch: 56
# Current epoch training loss: 0.9406327174515674
# Current epoch testing loss: 1.2566188398351523
# Current epoch: 57
# Current epoch training loss: 0.9380767693918342
# Current epoch testing loss: 1.2034309212931522
# Current epoch: 58
# Current epoch training loss: 0.9405472014423862
# Current epoch testing loss: 1.2396340291512193
# Current epoch: 59
# Current epoch training loss: 0.9354922158377511
# Current epoch testing loss: 1.1712511069883549
# Current epoch: 60
# Current epoch training loss: 0.9285581369433253
# Current epoch testing loss: 1.1711181759229166
# Current epoch: 61
# Current epoch training loss: 0.9267960252246791
# Current epoch testing loss: 1.3592619968549855
# Current epoch: 62
# Current epoch training loss: 0.9346053733227561
# Current epoch testing loss: 1.1664860369590333
# Current epoch: 63
# Current epoch training loss: 0.9384241683142526
# Current epoch testing loss: 1.2176218504833085
# Current epoch: 64
# Current epoch training loss: 0.933290699716229
# Current epoch testing loss: 1.179344916706763
# Current epoch: 65
# Current epoch training loss: 0.9259891348433411
# Current epoch testing loss: 1.2212146889739834
# Current epoch: 66
# Current epoch training loss: 0.9279931461354166
# Current epoch testing loss: 1.272236336306267
# Current epoch: 67
# Current epoch training loss: 0.9312568451884732
# Current epoch testing loss: 1.201829793489524
# Current epoch: 68
# Current epoch training loss: 0.9136554242841873
# Current epoch testing loss: 1.2061012898604881
# Current epoch: 69
# Current epoch training loss: 0.9024945628767644
# Current epoch testing loss: 1.4966236746250676
# Current epoch: 70
# Current epoch training loss: 0.9047926913155081
# Current epoch testing loss: 1.2871681342875292
# Current epoch: 71
# Current epoch training loss: 0.8922995790371911
# Current epoch testing loss: 1.2767839129201046
# Current epoch: 72
# Current epoch training loss: 0.8822434814134126
# Current epoch testing loss: 1.1764578819274902
# Current epoch: 73
# Current epoch training loss: 0.8873646966671694
# Current epoch testing loss: 1.2636182435272914
# Current epoch: 74
# Current epoch training loss: 0.8760440423098176
# Current epoch testing loss: 1.1379095921056526
# Current epoch: 75
# Current epoch training loss: 0.8842101545284019
# Current epoch testing loss: 1.200923931175077
# Current epoch: 76
# Current epoch training loss: 0.8755049730842537
# Current epoch testing loss: 1.1671684587062312
# Current epoch: 77
# Current epoch training loss: 0.8650616707286768
# Current epoch testing loss: 1.1908209729315666
# Current epoch: 78
# Current epoch training loss: 0.8488306145219437
# Current epoch testing loss: 1.1520077413713872
# Current epoch: 79
# Current epoch training loss: 0.8484107497677155
# Current epoch testing loss: 1.1414442945857943
# Current epoch: 80
# Current epoch training loss: 0.8547896774388356
# Current epoch testing loss: 1.1806493083837675
# Current epoch: 81
# Current epoch training loss: 0.839841060646735
# Current epoch testing loss: 1.2274130510194652
# Current epoch: 82
# Current epoch training loss: 0.8390946417320065
# Current epoch testing loss: 1.2168041522127724
# Current epoch: 83
# Current epoch training loss: 0.8385835934599102
# Current epoch testing loss: 1.248312536229942
# Current epoch: 84
# Current epoch training loss: 0.8375325317997551
# Current epoch testing loss: 1.2602053584181112
# Current epoch: 85
# Current epoch training loss: 0.8190645096194038
# Current epoch testing loss: 1.1000433966593088
# Current epoch: 86
# Current epoch training loss: 0.8176709725466339
# Current epoch testing loss: 1.1330841186688032
# Current epoch: 87
# Current epoch training loss: 0.8156929321405364
# Current epoch testing loss: 1.1440028418139152
# Current epoch: 88
# Current epoch training loss: 0.8256347512118908
# Current epoch testing loss: 1.1507403835427337
# Current epoch: 89
# Current epoch training loss: 0.820728556993531
# Current epoch testing loss: 1.1229696328264809
# Current epoch: 90
# Current epoch training loss: 0.8109045739788627
# Current epoch testing loss: 1.251793158841012
# Current epoch: 91
# Current epoch training loss: 0.8331600097829042
# Current epoch testing loss: 1.1457948303464704
# Current epoch: 92
# Current epoch training loss: 0.8015327505949067
# Current epoch testing loss: 1.1552624061022918
# Current epoch: 93
# Current epoch training loss: 0.8034363632418138
# Current epoch testing loss: 1.2909409013496438
# Current epoch: 94
# Current epoch training loss: 0.7990530002823275
# Current epoch testing loss: 1.1992181823943473
# Current epoch: 95
# Current epoch training loss: 0.7965103934866211
# Current epoch testing loss: 1.0921957335496313
# Current epoch: 96
# Current epoch training loss: 0.8027334857485435
# Current epoch testing loss: 1.1219179103822272
# Current epoch: 97
# Current epoch training loss: 0.7909923871219782
# Current epoch testing loss: 1.053593309095063
# Current epoch: 98
# Current epoch training loss: 0.7931744035528097
# Current epoch testing loss: 1.1599714513962645
# Current epoch: 99
# Current epoch training loss: 0.7872644936166159
# Current epoch testing loss: 1.0980316294631378

# %% [markdown]
# And finally visualize the training/validation process by showing the loss during each epoch (as below):

# %%
# TODO: Plot the visualization of the training process as below.
# During next laboratory you will use a better tool: TensorBoard

# %% [markdown]
# Do you see any problems? What went wrong? What whould happen after inreasing the number of training epochs?
#
# You have just finished the training of the neural network. The next task is to analyze the obtained results.

# %% [markdown]
# ### Part V - Result Analysis

# %% [markdown]
# In the last part of the Laboratory you are going to analyze the results. First, you are going to show the confusion matrices for the training and testing sets. Then, you will visualize the cases for which the network failed.
#
# Start with creating function responsible for accumulating the results. The function should perform a single pass through a dataloader and accumulate all predicitions, together with the corresponding group truth labels.

# %%
def accumulate_predictions(model, dataloader):
  predictions = []
  targets = []
  device = "cuda:0"
  model.eval()
  with tc.set_grad_enabled(False):
      print(f"Dataset size: {len(dataloader.dataset)}")
      for images, classes in dataloader:
        pass # TODO
  return predictions, targets

training_predictions, training_targets = accumulate_predictions(model, training_dataloader)
testing_predictions, testing_targets =  accumulate_predictions(model, testing_dataloader)
# Out:
# Dataset size: 2870
# Dataset size: 394

# %% [markdown]
# Now use the function to accumulate the results for training/testing dataloaders and use **sklearn** to show the confusion matrices and classification summary.

# %%
import sklearn.metrics as metrics
target_names = ["Glioma", "Meningioma", "Healthy", "Pituitary"]
#Classes dict: {'glioma_tumor': 0, 'meningioma_tumor': 1, 'no_tumor': 2, 'pituitary_tumor': 3}

# TODO
# Out:
# Confusion matrix training: [[432   9  58 327]
#  [  0 378   0  17]
#  [  0   1 826   0]
#  [  0  22  67 733]]
#               precision    recall  f1-score   support
#
#       Glioma       1.00      0.52      0.69       826
#   Meningioma       0.92      0.96      0.94       395
#      Healthy       0.87      1.00      0.93       827
#    Pituitary       0.68      0.89      0.77       822
#
#     accuracy                           0.83      2870
#    macro avg       0.87      0.84      0.83      2870
# weighted avg       0.86      0.83      0.82      2870
#
# Confusion matrix testing:: [[ 10  48  11  31]
#  [  0 104   0   1]
#  [  0  12  48  14]
#  [  0  17   3  95]]
#               precision    recall  f1-score   support
#
#       Glioma       1.00      0.10      0.18       100
#   Meningioma       0.57      0.99      0.73       105
#      Healthy       0.77      0.65      0.71        74
#    Pituitary       0.67      0.83      0.74       115
#
#     accuracy                           0.65       394
#    macro avg       0.76      0.64      0.59       394
# weighted avg       0.75      0.65      0.59       394

# %% [markdown]
# What went wrong? Why the results for the training set are so different from the testing set?
#
# Finally, prepare the visualization similar to the one below but showing example of incorrectly classified cases. Show next to the given image the real class and the predicted one.

# %%
# TODO: Prepare the visualization as below

# TODO

# %% [markdown]
# What can you say about the results using the confusion matrices and the visualization? Is the classification working correctly? What's wrong? Do you have any idea how to improve the results? Hint: visually examine the images for each class, both in the training and the testing set.
#
# We will continue the classification topic during the next laboratory using different dataset and a pretrained ResNet18 architecture.

# %% [markdown]
# ### Conclusion

# %% [markdown]
# Congratulations, you have implemented the gradient descent method, the supervised training pipeline and prepared the training setup for the medical image classification.
#
# After the laboratory you should:
# <ul>
#   <li> Understand the intuition behind the gradient descent method.
#   <li> Be able to implement your own training pipeline for the supervised learning.
#   <li> Modify the training hyperparameters to verify their influence on the final results.
# </ul>
#
# During the next laboratory you are going to extend the knowledge for classification of XRay images by image augmentation, transfer learning from pretrained ResNet18 network, and logging using TensorBoard. You will also extend the evaluation beyond the confusion matrix and simple visualization.
